# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Figure 1

plt.rcParams["figure.figsize"] = (10,5)

a=np.array([[1,0.25119996,0.994,0.12859998,0.87140002],
[0.9,0.1846,0.9926,0.096,0.904],
[0.8,0.20039997,0.99300003,0.10369997,0.89630003],
[0.7,0.1178,0.98840004,0.06469998,0.93530002],
[0.6,0.104399994,0.98620003,0.059099982,0.940900018],
[0.5,0.036599997,0.9672001,0.0346999485,0.9653000515],
[0.4,0.021799998,0.95399994,0.033900029,0.966099971],
[0.3,0.0117999995,0.92560005,0.04309997475,0.9569000253],
[0.2,0.0062,0.8664,0.0699,0.9301],
[0.1,0.0062,0.79300004,0.10659998,0.89340002],
[0,0.0063999994,0.71059996,0.1479000197,0.8520999803]])

names = ['p1','positive','negative','total pos','total neg']

with sns.axes_style('darkgrid'):
    for i in range(4):
        sns.lineplot(x=a[:,0], y=a[:,i+1],label=names[i+1]) 


plt.xlabel('Positive distribution', fontsize=20)
plt.ylabel('Fraction', fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.grid(True)
plt.legend(fontsize=16)
plt.show()

# %%
# Figure 2

plt.rcParams["figure.figsize"] = (10,5)

a=np.array([[1,0.9968,0.2222,0.8873,0.1127],
[0.9,0.9954,0.1666,0.9144,0.0856],
[0.8,0.99619997,0.16239999,0.91689999,0.08310001],
[0.7,0.997,0.07659999,0.960200005,0.039799995],
[0.6,0.99660003,0.058199998,0.969200016,0.030799984],
[0.5,0.9922,0.0168,0.9877,0.0123],
[0.4,0.9928,0.004,0.9944,0.0056],
[0.3,0.98620003,0.004,0.991100015,0.008899985],
[0.2,0.9872,0.0008,0.9932,0.0068],
[0.1,0.9775999,0,0.98879995,0.01120005],
[0,0.9518001,0.0002,0.97580005,0.02419995]])

names = ['p1','positive','negative','total pos','total neg']

with sns.axes_style('darkgrid'):
    for i in range(4):
        sns.lineplot(x=a[:,0], y=a[:,i+1],label=names[i+1]) 


plt.xlabel('Negative distribution', fontsize=20)
plt.ylabel('Fraction', fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.grid(True)
plt.legend(fontsize=16)
plt.show()

# %%
# Figure 3

plt.rcParams["figure.figsize"] = (16,4)

a_02=np.array([[1,0.191,0.8982,0.1464,0.8536],
[0.9,0.1823999,0.88119996,0.15059997,0.84940003],
[0.8,0.0984001,0.9358,0.08130005,0.91869995],
[0.7,0.09339998,0.9858,0.05379999,0.94620001],
[0.6,0.014400001,0.99979997,0.0073000155,0.9926999845],
[0.5,0.0034,1,0.0017,0.9983],
[0.4,0.0004,1,0.0002,0.9998],
[0.3,0.009,1,0.0045,0.9955],
[0.2,0.7216,0.26580005,0.727899975,0.272100025],
[0.1,0.8982,0.22,0.8391,0.1609],
[0,0.931,0.11660005,0.907199975,0.092800025]])

a_05=np.array([[1,0.1872,0.91120005,0.137999975,0.862000025],
[0.9,0.0956,0.9463999,0.07460005,0.92539995],
[0.8,0.1418,0.9578001,0.09199995,0.90800005],
[0.7,0.07620002,0.9958,0.04020001,0.95979999],
[0.6,0.13440003,0.9922,0.071100015,0.928899985],
[0.5,0.81219995,0.2944,0.758899975,0.241100025],
[0.4,0.9956,0.31120002,0.84219999,0.15780001],
[0.3,0.9774,0.188,0.8947,0.1053],
[0.2,0.9594001,0.1436,0.90790005,0.09209995],
[0.1,0.88780004,0.2026,0.84260002,0.15739998],
[0,0.85220003,0.04400004,0.904099995,0.095900005]])

a_08=np.array([[1,0.2424,0.73780006,0.25229997,0.74770003],
[0.9,0.323,0.77760005,0.272699975,0.727300025],
[0.8,0.97340006,0.6593999,0.65700008,0.34299992],
[0.7,1,0.084,0.958,0.042],
[0.6,1,0.015999999,0.9920000005,0.0079999995],
[0.5,1,0.009799999,0.9951000005,0.0048999995],
[0.4,1,0.0336,0.9832,0.0168],
[0.3,0.9992,0.0546,0.9723,0.0277],
[0.2,0.999,0.113800004,0.942599998,0.057400002],
[0.1,0.98679996,0.05639998,0.96519999,0.03480001],
[0,0.96959996,0.1568,0.90639998,0.09360002]])


names = ['p1','positive','negative','total pos','total neg']
with sns.axes_style('darkgrid'):
    plt.subplot(131) 
    for i in range(4):
        sns.lineplot(x=a_02[:,0], y=a_02[:,i+1],label=names[i+1]) 

    plt.xlabel('Positive fraction', fontsize=16)
    plt.ylabel('Fraction', fontsize=16)
    # plt.title('0.2')
    # plt.grid()
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)

    plt.subplot(132) 
    for i in range(4):
        sns.lineplot(x=a_05[:,0], y=a_05[:,i+1]) 

    plt.xlabel('Positive fraction', fontsize=16)
    plt.ylabel('Fraction', fontsize=16)
    # plt.title('0.5')
    # plt.grid()
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)

    plt.subplot(133) 
    for i in range(4):
        sns.lineplot(x=a_08[:,0], y=a_08[:,i+1]) 

    plt.xlabel('Positive fraction', fontsize=16)
    plt.ylabel('Fraction', fontsize=16)
    # plt.title('0.8')
    # plt.grid()
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/pengfei/anaconda3/envs/icl/lib/python3.8/site-packages/matplotlib/pyplot.py'>
