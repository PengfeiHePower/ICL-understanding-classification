# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pos_matrix = np.array([[0.486,0.149,0.234,0.305,0.388,0.519,0.577,0.652,0.686,0.662,0.741],
                       [0.973,0.557,0.237,0.237,0.33,0.449,0.559,0.635,0.637,0.654,0.655],
                       [0.994,0.896,0.551,0.243,0.208,0.333,0.427,0.523,0.596,0.622,0.679],
                       [0.993,0.989,0.876,0.58,0.292,0.242,0.327,0.44,0.552,0.602,0.595],
                       [0.982,0.988,0.976,0.835,0.552,0.304,0.212,0.307,0.432,0.513,0.623],
                       [0.972,0.988,0.995,0.967,0.845,0.564,0.304,0.255,0.317,0.41,0.514],
                       [0.944,0.972,0.985,0.991,0.973,0.848,0.564,0.279,0.268,0.329,0.414],
                       [0.956,0.974,0.967,0.982,0.991,0.967,0.846,0.564,0.256,0.222,0.333],
                       [0.922,0.944,0.958,0.971,0.981,0.991,0.979,0.872,0.568,0.199,0.193],
                       [0.936,0.92,0.933,0.966,0.973,0.988,0.992,0.99,0.914,0.527,0.17],
                       [0.905,0.934,0.927,0.958,0.956,0.978,0.978,0.991,0.991,0.972,0.481]])

row_names = np.around(np.linspace(1, 0, 11), decimals=1)
column_names = np.around(np.linspace(1, 0, 11), decimals=1)
sns.heatmap(pos_matrix, cmap='coolwarm', annot=True, xticklabels=column_names, yticklabels=row_names)

# Add titles and labels if needed
plt.title('Positive distribution')
plt.xlabel('negative example')
plt.ylabel('positive example')
# Out:
# Text(50.722222222222214, 0.5, 'negative example')

# %%
# Out:
# Text(50.722222222222214, 0.5, 'p2')
